# %%
import tensorflow as tf
from tensorflow import keras
import numpy as np
from nltk.corpus import brown
from tensorflow.keras.models import Sequential
from tensorflow.keras import Input
import codecs, os, json, operator, pickle
from random import shuffle
from tensorflow.keras.layers import Embedding
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential
from sklearn.metrics.pairwise import cosine_similarity

dataset = []
                            
for word in brown.words():
    dataset.append(word)


onehotrep=[tf.keras.preprocessing.text.one_hot(words, len(dataset)) for words in dataset]



sent_length=8
embedded_docs=pad_sequences(onehotrep,padding='pre',maxlen=sent_length)


dim=10

model=Sequential()
embeddings = Embedding(len(dataset),10,input_length=len(dataset))

model.add(embeddings);

model.compile('adam','mse')

model.summary()

gender_specific = []
with open('C://Users/rschm/OneDrive/Documents/male_word_file.txt') as f:
    for l in f:
        gender_specific.append(l.strip())
with open('C://Users/rschm/OneDrive/Documents/female_word_file.txt') as f:
    for l in f:
        gender_specific.append(l.strip())

with codecs.open('C://Users/rschm/OneDrive/Documents/gender_specific_full.json') as f:
    gender_specific.extend(json.load(f))

definitional_pairs = [['she', 'he'], ['herself', 'himself'], ['her', 'his'], ['daughter', 'son'], 
                      ['girl', 'boy'], ['mother', 'father'], ['woman', 'man'], ['mary', 'john'], 
                      ['gal', 'guy'], ['female', 'male']]
definitional_words = []

for pair in definitional_pairs:
    for word in pair:
        definitional_words.append(word)

onehotrep=[tf.keras.preprocessing.text.one_hot(words, len(definitional_words)) for words in definitional_words]
print(np.shape(onehotrep))

sent_length=8
embedded_docs=pad_sequences(onehotrep,padding='pre',maxlen=sent_length)


dim=10
model = Sequential()
def_wv =  Embedding(len(definitional_words),10,input_length=len(definitional_words))
model.add(def_wv);

model.compile('adam','mse')

model.summary()
